# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.0001, 3, 100)
y = x**x
plt.plot(x, y, 'r-', linewidth=3)
plt.show()

# %%
x = np.linspace(0, 1, 100)
y = x**x
plt.plot(x, y, 'r-', mec='k')
plt.show()

# %%
import math
math.factorial(10) # 阶乘
# Out:
# 3628800
